# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/EENG-310-Signals-and-Systems/blob/main/EENG_310_HW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp

# %% [markdown]
# A. Draw the Direct Form II realization of the LTI system whose frequency response is:
#
# $$ H(w) = \frac{(4-6\omega^2) + j5\omega}{(2-\omega^2) + j3\omega}$$
#
#
# You should get:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. An unstable LTI system has the impulse response
#
# $$h(t) = e^t u(t) - e^{-5t} u(t).$$
#
# For proportional feedback with $G(s)=K$, compute $K$ to realize
#
# 1. The closed-loop poles at {-1,-3} (ans: $K=4/3$)
# 2. The closed loop system is critically damped. (ans: $K=3/2$)

# %% [markdown]
# C. An unstable LTI system has an impulse response
#
# $$h(t) = (e^{3t} - e^{2t})u(t).$$
#
# 1. Show that proportional feedback alone cannot stabalize the system.
# 2. Show that derivative feedback can stabalize the system with a slow pole at $p\ge -\sqrt{6}$.
# 3. Show that $G(s)=K_1 + K_2s$ can be used to place both poles at -10. Compute $K_1$, and $K_2$ to accomplish this. (ans: $K_1=94$, $K_2=25$)

# %% [markdown]
# D. An unstable LCCDE
#
# $$ \frac{d^2y}{dt^2} - 2\frac{dy}{dt} + 5y(t) = x(t)$$
#
# Using proportional plus derivative feedback with
#
# $$ G(s) = K_1 + K_2 s$$
#
# compute $K_1$, and $K_2$ to
#
# 1. make the closed-loop system stable and critically damped
# 2. make the steady state step response have a value of 0.01.
#
# (Ans: $K_1=95$, $K_2=22$)
