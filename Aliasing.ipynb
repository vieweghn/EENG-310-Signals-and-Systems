# %% [markdown]
# <a href="https://colab.research.google.com/github/vieweghn/EENG-310-Signals-and-Systems/blob/main/Aliasing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ts=0.001
omegas = 2*np.pi/ts
omega0 = .6*omegas

# %%
fig = plt.figure(figsize=(10,3))
t = np.linspace(0,0.010,1000)
td = np.arange(0,.01,.001)
plt.stem(td,np.cos(omega0*td))
plt.plot(t,np.cos(omega0*t),'r--')
plt.plot(t,np.cos(0.4*omegas*t),'g--')
plt.grid()

# %%
ts=0.001
omegas = 2*np.pi/ts
omega0 = .1*omegas

# %%
fig = plt.figure(figsize=(10,3))
t = np.linspace(0,0.010,1000)
td = np.arange(0,.01,.001)
plt.stem(td, np.sin(omega0*td)**2)
plt.plot(t,np.sin(omega0*t)**2, 'b--')
plt.grid()

# %%
fig = plt.figure(figsize=(10,3))
t = np.linspace(0,0.010,1000)
td = np.arange(0,.01,.001)
plt.plot(t,np.cos(omega0*t))
plt.stem(td,np.ones(len(td)))
plt.grid()
